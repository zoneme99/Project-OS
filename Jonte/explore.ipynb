# %%
import pandas as pd
import matplotlib.pyplot as plt

noc = "HUN"
df = pd.read_csv("athlete_events.csv")
hungary = df[df["NOC"] == noc]
hungary
# Out:
#             ID              Name Sex   Age  Height  Weight     Team  NOC  \
# 208         99         Pter Abay   M  30.0   181.0    79.0  Hungary  HUN
# 209        100  Oszkr Abay-Nemes   M  22.0     NaN     NaN  Hungary  HUN
# 210        100  Oszkr Abay-Nemes   M  22.0     NaN     NaN  Hungary  HUN
# 884        507      Attila brahm   M  21.0   192.0    88.0  Hungary  HUN
# 885        507      Attila brahm   M  21.0   192.0    88.0  Hungary  HUN
# ...        ...               ...  ..   ...     ...     ...      ...  ...
# 270750  135406     Bla Zulawszky   M  38.0     NaN     NaN  Hungary  HUN
# 270751  135406     Bla Zulawszky   M  38.0     NaN     NaN  Hungary  HUN
# 270752  135406     Bla Zulawszky   M  42.0     NaN     NaN  Hungary  HUN
# 270753  135406     Bla Zulawszky   M  42.0     NaN     NaN  Hungary  HUN
# 271020  135526      Dniel Zwickl   M  27.0   178.0    71.0  Hungary  HUN
#
#               Games  Year  Season       City         Sport  \
# 208     1992 Summer  1992  Summer  Barcelona       Fencing
# 209     1936 Summer  1936  Summer     Berlin      Swimming
# 210     1936 Summer  1936  Summer     Berlin      Swimming
# 884     1988 Summer  1988  Summer      Seoul      Canoeing
# 885     1988 Summer  1988  Summer      Seoul      Canoeing
# ...             ...   ...     ...        ...           ...
# 270750  1908 Summer  1908  Summer     London       Fencing
# 270751  1908 Summer  1908  Summer     London       Fencing
# 270752  1912 Summer  1912  Summer  Stockholm       Fencing
# 270753  1912 Summer  1912  Summer  Stockholm       Fencing
# 271020  2012 Summer  2012  Summer     London  Table Tennis
#
#                                                 Event   Medal
# 208                         Fencing Men's Sabre, Team  Silver
# 209               Swimming Men's 100 metres Freestyle     NaN
# 210     Swimming Men's 4 x 200 metres Freestyle Relay  Bronze
# 884          Canoeing Men's Kayak Doubles, 500 metres  Bronze
# 885          Canoeing Men's Kayak Fours, 1,000 metres    Gold
# ...                                               ...     ...
# 270750                 Fencing Men's epee, Individual     NaN
# 270751                Fencing Men's Sabre, Individual  Silver
# 270752                 Fencing Men's Foil, Individual     NaN
# 270753                Fencing Men's Sabre, Individual     NaN
# 271020                     Table Tennis Men's Singles     NaN
#
# [6607 rows x 15 columns]

# %%
sportcount = hungary['Sport'].value_counts()
sportcount
# Out:
# Sport
# Gymnastics                   1242
# Athletics                     767
# Swimming                      719
# Fencing                       628
# Canoeing                      306
# Water Polo                    304
# Shooting                      298
# Wrestling                     279
# Handball                      205
# Rowing                        194
# Football                      132
# Cycling                       121
# Boxing                        110
# Weightlifting                  99
# Alpine Skiing                  99
# Modern Pentathlon              93
# Art Competitions               87
# Equestrianism                  84
# Sailing                        77
# Judo                           76
# Speed Skating                  68
# Biathlon                       67
# Figure Skating                 61
# Basketball                     61
# Tennis                         60
# Short Track Speed Skating      56
# Cross Country Skiing           51
# Volleyball                     47
# Ice Hockey                     40
# Diving                         39
# Table Tennis                   36
# Bobsleigh                      19
# Hockey                         15
# Archery                        14
# Triathlon                      12
# Ski Jumping                    11
# Rhythmic Gymnastics             7
# Badminton                       7
# Nordic Combined                 6
# Polo                            5
# Synchronized Swimming           4
# Taekwondo                       1
# Name: count, dtype: int64

# %%
major_sports = sportcount[0:4].sum()
minor_sports = sportcount[4:].sum()

plt.pie([major_sports, minor_sports], labels=["Gymnastics, Athletics, Swimming, Fencing", "Other"], autopct="%1.1f%%")
plt.show()
