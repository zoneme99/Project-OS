# %%
import pandas as pd
import plotly_express as px

df = pd.read_csv("../Data/athlete_events.csv")

# %%
df["Sport"].unique()
# df[df["Sport"] == "Canoeing"]["Event"].unique()

# Rowing, Canoeing, Sailing

# Scatter Height and Weight
# Line Age and Year
# Pie Medals alla games combined, each individual
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
df.sort_values("Year", ascending=False, inplace=True)
df.dropna(inplace=True)
"""
fig = px.scatter(
    df.head(50), x="Weight", y="Height", size="Age", color="NOC", 
    size_max=79, animation_frame="Year", animation_group="NOC", 
    title="Gapminder", range_x=[120, 230], range_y=[25,220] 
    )
"""
df_water_craft = df[(df["Sport"]=="Sailing") | (df["Sport"]=="Rowing") | (df["Sport"]=="Canoeing") ] 
fig = px.scatter(
    df_water_craft, x="Weight", y="Height", color="Sport", size="Age", 
    animation_frame="Year", animation_group="NOC",
    range_y=[120, 230], range_x=[25,220], 
    title="Height and Weight Distrubution"
    )
fig.show()

# %%
df_new = pd.DataFrame()
df_new["Rowing"] = df_water_craft[df.Sport == "Rowing"].groupby("Year")["Age"].mean()
df_new["Rowing"] = df_water_craft[df.Sport == "Rowing"].groupby("Year")["Age"].mean()
#fig = px.line(, y=["Gold", "Silver", "Bronze"], color_discrete_sequence=['Gold', 'Silver', 'Brown'])

#fig.show()
# Out:
# C:\Users\adamt\AppData\Local\Temp\ipykernel_6188\4069503267.py:2: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\adamt\AppData\Local\Temp\ipykernel_6188\4069503267.py:3: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
df_new = pd.DataFrame()
df_new["Rowing"] = df_water_craft[df.Sport == "Rowing"].groupby("Year")["Age"].mean()
df_new["Canoeing"] = df_water_craft[df.Sport == "Canoeing"].groupby("Year")["Age"].mean()
df_new["Sailing"] = df_water_craft[df.Sport == "Sailing"].groupby("Year")["Age"].mean()
df_new.dropna(inplace=True)
fig = px.line(df_new, y=["Rowing", "Canoeing", "Sailing"])

fig.show()
# Out:
# C:\Users\adamt\AppData\Local\Temp\ipykernel_6188\3065330533.py:2: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\adamt\AppData\Local\Temp\ipykernel_6188\3065330533.py:3: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\adamt\AppData\Local\Temp\ipykernel_6188\3065330533.py:4: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
def  unique_medals( df ):
    set_year_medal_event = set()
    for idx, row in df.dropna( subset=["Medal"] ).iterrows():
        set_year_medal_event.add(f" {row['Year']}|{row['Event']}|{row['NOC']}|{row['Medal']} ")
    len(set_year_medal_event)

    year = [ row.split("|")[0][1:] for row in set_year_medal_event ]
    event = [ row.split("|")[1] for row in set_year_medal_event ]
    noc = [ row.split("|")[2] for row in set_year_medal_event ]
    medal = [ row.split("|")[3][:-1] for row in set_year_medal_event ]

    df_um = pd.DataFrame(   
        {"Year":year, "Medal":medal, "NOC":noc, "Event":event}
    ) 

    return df_um


df_new = unique_medals( df_water_craft[df["Medal"] == "Gold"] )

df_new.head()
df_new = df_new.groupby("NOC", as_index=False)["Medal"].count()
#df_new.set_index("NOC", inplace=True)
df_new.sort_values("Medal", ascending=False, inplace=True)
fig = px.pie(df_new[0:17], values='Medal', names='NOC')
fig.show()
# Out:
# C:\Users\adamt\AppData\Local\Temp\ipykernel_6188\1572865721.py:19: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
